# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/log.csv', sep = ';')
df = df.replace(',', '.', regex=True)
df = df.astype(float)
df = df.rename(index={ 0: 'ERBB4', 1: 'H2a', 2: 'H2B', 3: 'H3', 4: 'H4'})
df
# Out:
#             human       mouse   zebrafish  drosophila  c elegans    ciliate  \
# ERBB4  300.000000  300.000000  300.000000  129.841637  68.038579  27.452225
# H2a     90.306273   83.340084   80.974694   68.630784  66.185087  56.759451
# H2B     87.441291   86.823909   82.234331   58.481486  65.223299  50.440093
# H3      95.659556   95.812479   94.752027   95.027334  93.350665  85.075204
# H4      66.962574   67.119186   67.946922   67.095826  67.211125  44.707744
#
#            yeast  methanocaldococcus  thermococcus   tuberculosis    e coli
# ERBB4  16.185752            1.000000      0.568636       8.266803  0.086186
# H2a    62.051587            3.000000      2.154902       0.397940  0.214670
# H2B    78.057478            0.000000      0.769551       0.000000  0.000000
# H3     86.480172            2.468521      1.244125       0.000000  0.045757
# H4     51.966576            4.085128      4.480172       1.161151  0.000000

# %%
f, ax = plt.subplots(figsize=(20,5))
colors = ['#000000','#1c001a','#290026','#40003b','#52024b','#b700cf','#ffffff']
ax = sns.heatmap(df, cmap = colors, annot = df)
ax.set_yticklabels(df.index.values)
plt.show()
